# %%
# !pip install nsepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for nsepy: filename=nsepy-0.8-py3-none-any.whl size=36084 sha256=f0a089a7c5dda22501a53da0c2fd8376965c39e00d0d8912794de98b421d982c
#   Stored in directory: /root/.cache/pip/wheels/32/ab/d9/78ceea14cdf6de83376082b3cb0c2999fd77f823e35c47b9ec
# Successfully built nsepy
# ...

# %%
import pandas as pd
df = pd.read_csv('/content/top100companies.csv')
import nsepy
from datetime import date , timedelta

# %%
result=nsepy.get_history('BSE',start=date.today()-timedelta(days=700),end=date.today()-timedelta(days=0))
result=result.drop({"Series","Prev Close","Symbol","Open","High","Low","Last","Close","Deliverable Volume","Turnover","Trades","Volume","%Deliverble"}, axis='columns')
result.rename(columns = {'VWAP': 'Sensex'}, inplace = True)
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 479 entries, 2020-07-10 to 2022-06-10
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sensex  479 non-null    float64
# dtypes: float64(1)
# memory usage: 7.5+ KB

# %%
for x in range(100):
  t=df['Symbol'][x]
  data_t=nsepy.get_history(t,start=date.today()-timedelta(days=700),end=date.today()-timedelta(days=0))
  data_t  
  data_t=data_t.drop({"Series","Prev Close","Symbol","Open","High","Low","Last","Close","Deliverable Volume","Turnover","Trades","Volume","%Deliverble"}, axis='columns')
  data_t.rename(columns = {'VWAP': t}, inplace = True) 
  result = pd.concat([data_t,result], axis=1, join="outer")

# %%
result = pd.read_csv('/content/C__Users_dsrav_Desktop_data for Data & analytics.csv')

# %%
result.head()
# Out:
#             ADANITRANS  KANSAINER      PEL   3MINDIA    GLAXO  HINDALCO  \
# Date
# 2020-07-10      240.52     433.80  1452.34  19482.85  1485.34    162.43
# 2020-07-13      250.13     435.35  1449.23  19690.04  1503.01    167.28
# 2020-07-14      249.45     437.51  1391.44  20038.16  1501.80    164.91
# 2020-07-15      248.09     446.58  1419.07  20291.93  1544.29    166.71
# 2020-07-16      241.11     451.15  1374.28  20398.13  1547.39    163.90
#
#               PNB  TATAMOTORS    HONAUT  WHIRLPOOL  ...     ITC  BHARTIARTL  \
# Date                                                ...
# 2020-07-10  35.18      107.29  29222.30    2205.82  ...  194.90      573.33
# 2020-07-13  34.73      109.45  28963.11    2195.98  ...  197.15      580.46
# 2020-07-14  33.67      105.61  28438.25    2172.68  ...  196.57      589.99
# 2020-07-15  33.55      104.91  28407.36    2186.23  ...  197.63      574.90
# 2020-07-16  32.85      102.04  28273.96    2192.78  ...  193.53      561.59
#
# ...

# %%
result.nunique()
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 479 entries, 2020-07-10 to 2022-02-11
# Columns: 101 entries, ADANITRANS to Sensex
# dtypes: float64(98), object(3)
# memory usage: 381.7+ KB

# %%
result.to_csv(r'C:\Users\dsrav\Desktop\data for Data & analytics.csv')

# %%
result.nunique()
# Out:
# ADANITRANS    309
# KANSAINER     470
# PEL           478
# 3MINDIA       479
# GLAXO         475
#              ...
# HDFCBANK      477
# HINDUNILVR    476
# TCS           479
# RELIANCE      478
# Sensex        476
# Length: 101, dtype: int64

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 479 entries, 2020-07-10 to 2022-02-11
# Columns: 101 entries, ADANITRANS to Sensex
# dtypes: float64(98), object(3)
# memory usage: 397.9+ KB

# %% [markdown]
# so 'CADILAHC','INFRATEL','GSKCONS' have 0 non null values so i want to
# drop those columns.

# %%
result=result.drop({'CADILAHC','INFRATEL','GSKCONS'},axis = 'columns')

# %% [markdown]
#  ADANITRANS with 77 non null values,ADANIGREEN with 180 non null values and all other 95 companies with 204 non null values.

# %%
result.columns[0]
# Out:
# 'ADANITRANS'

# %%
for i in range (98):

  if len(result[result.columns[i]]) < 479:
    result[result.columns[i]]=result[result.columns[i]].fillna(result[result.columns[i]].mean())

# %%
import seaborn as sns
sns.heatmap(result.corr())
data=['x','y',9]

# %% [markdown]
# columns = result.columns.values.tolist()
# columns[0]

# %%
result1=result

# %%
columns = result.columns

# %%
k=corr = abs(result.corr()[columns[0]][columns[1]])
print(k)
# Out:
# 0.4050309385736553

# %%
columns1 = result1.columns
for x in range(98):
  for y in range(x+1,98):
    if (columns[x] != 'Sensex' and  columns[y] != 'Sensex'):
      corr = abs(result.corr()[columns[x]][columns[y]]) 
      if corr>=0.9 :
         temp1=abs(result.corr()[columns[x]]['Sensex'])
         temp2=abs(result.corr()[columns[y]]['Sensex'])
         if (temp1>temp2):
           if columns[y] in columns1:
             result1=result1.drop(columns[y],axis = 'columns')
             columns1 = result1.columns
         else:
           if columns[x] in columns1:           
             result1=result1.drop(columns[x],axis = 'columns')
             columns1 = result1.columns

# %%
result1.info()
columns1 = result1.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 479 entries, 2020-07-10 to 2022-02-11
# Data columns (total 40 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   KANSAINER   479 non-null    float64
#  1   3MINDIA     479 non-null    float64
#  2   GLAXO       479 non-null    float64
#  3   PNB         479 non-null    float64
#  4   HONAUT      479 non-null    float64
#  5   WHIRLPOOL   479 non-null    float64
#  6   AUROPHARMA  479 non-null    float64
#  7   MUTHOOTFIN  479 non-null    float64
#  8   MRF         479 non-null    float64
#  9   LTI         479 non-null    float64
#  10  NAUKRI      479 non-null    float64
#  11  LUPIN       479 non-null    float64
#  12  BOSCHLTD    479 non-null    float64
#  13  YESBANK     479 non-null    float64
#  14  HINDPETRO   479 non-null    float64
#  15  PETRONET    479 non-null    float64
#  16  HEROMOTOCO  479 non-null    float64
#  17  BIOCON      479 non-null    float64
# ...

# %% [markdown]
# till know what i did is:
# filling the missing data with relavent process(filling with mean and with lr)
# and i droped the column with more corrilation with another independent column and less corrilation with sensex(dependent variable).

# %%
result1[columns1]
# Out:
#             KANSAINER   3MINDIA    GLAXO    PNB    HONAUT  WHIRLPOOL  \
# Date
# 2020-07-10     433.80  19482.85  1485.34  35.18  29222.30    2205.82
# 2020-07-13     435.35  19690.04  1503.01  34.73  28963.11    2195.98
# 2020-07-14     437.51  20038.16  1501.80  33.67  28438.25    2172.68
# 2020-07-15     446.58  20291.93  1544.29  33.55  28407.36    2186.23
# 2020-07-16     451.15  20398.13  1547.39  32.85  28273.96    2192.78
# ...               ...       ...      ...    ...       ...        ...
# 2022-02-07     538.43  24780.70  1578.67  42.22  44612.35    1785.69
# 2022-02-08     524.36  24275.68  1547.95  41.49  44609.18    1791.74
# 2022-02-09     514.86  24236.75  1565.62  41.68  44543.56    1784.44
# 2022-02-10     509.53  23924.80  1554.32  41.24  44616.27    1777.16
# 2022-02-11     498.73  23036.26  1569.20  40.13  44357.06    1769.21
#
#             AUROPHARMA  MUTHOOTFIN       MRF      LTI  ...  SHREECEM  \
# Date                                                   ...
# ...

# %%
for t in range(40):
  temp=max(result1[columns1[t]])
  result1[columns1[t]]=result[columns1[t]]/temp

# %%
result1.head()
# Out:
#             KANSAINER   3MINDIA     GLAXO       PNB    HONAUT  WHIRLPOOL  \
# Date
# 2020-07-10   0.649790  0.643078  0.782854  0.756722  0.591883   0.819064
# 2020-07-13   0.652112  0.649916  0.792167  0.747042  0.586633   0.815410
# 2020-07-14   0.655348  0.661407  0.791529  0.724242  0.576002   0.806758
# 2020-07-15   0.668933  0.669783  0.813924  0.721661  0.575377   0.811789
# 2020-07-16   0.675779  0.673288  0.815558  0.706604  0.572675   0.814222
#
#             AUROPHARMA  MUTHOOTFIN       MRF       LTI  ...  SHREECEM  \
# Date                                                    ...
# 2020-07-10    0.785673    0.639037  0.685862  0.279533  ...  0.709498
# 2020-07-13    0.779635    0.650446  0.682676  0.291896  ...  0.709253
# 2020-07-14    0.777645    0.642964  0.675369  0.295838  ...  0.697419
# 2020-07-15    0.795059    0.642634  0.676567  0.300247  ...  0.693815
# 2020-07-16    0.796666    0.659954  0.665214  0.304827  ...  0.684961
#
# ...

# %%
y = result1['Sensex']
X = result1[result1.columns.difference(['Sensex'])]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
h = LinearRegression()
h.fit(X_train,y_train)
print(h.intercept_) # to retrieve theta_0
print(h.coef_)
# Out:
# 0.16795645206967025
# [-0.05469923 -0.07163476  0.03516623 -0.29140254  0.79987378  0.76576021
#   0.09452258 -0.2758627  -0.04694394 -0.20782839 -0.2518033   0.0878265
#   0.43936118  0.00519959 -0.26201769  0.17289247  0.46106164  1.10573503
#   0.63848278 -1.11217914 -0.74764323 -0.89724975  0.37607935  0.35958828
#  -0.28386773 -0.26827889 -0.18624168  0.54727665  0.11348103  0.1490465
#   0.34201566  0.83928355 -0.13589881 -0.70632839 -0.23128605 -0.7899729
#   0.54203521 -0.36720444 -0.44101839]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as seabornInstance
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
y_pred = h.predict(X_test)
compare = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
compare
# Out:
#               Actual  Predicted
# Date
# 2020-07-31  0.171927   0.190964
# 2021-01-05  0.215107   0.194956
# 2021-01-29  0.199320   0.266772
# 2022-04-01  0.312914   0.340061
# 2021-03-12  0.197156   0.221938
# ...              ...        ...
# 2021-11-12  0.478049   0.467771
# 2021-11-15  0.501812   0.478613
# 2020-12-10  0.212671   0.150511
# 2022-01-18  0.685355   0.665804
# 2021-04-09  0.202817   0.181234
#
# [96 rows x 2 columns]

# %%
fig,(ax1) = plt.subplots(1, figsize = (12,6))
ax1.scatter (y_pred, y_test, s = 8)
plt.plot(y_test,y_pred, color = 'black', linewidth = 2)
plt.show()
